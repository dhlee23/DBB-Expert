# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target,
                                                   stratify=iris.target,
                                                   test_size= 0.3, random_state = 11)

# %%
model = DecisionTreeClassifier(random_state = 11)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=11)

# %%
print(f" 학습 Accuracy : {model.score(X_train, y_train):.3f}\n")
print(f" 테스트 Accuracy : {model.score(X_test, y_test):.3f}")
# Out:
#  학습 Accuracy : 1.000
#
#  테스트 Accuracy : 0.978

# %% [markdown]
# ## 시각화
#
# ### graphviz 설치 후 python wrapper 추가 설치
#
# https://graphviz.org/download
#
# ### windows의 경우, exe 파일 관리자 권한으로 설치 하며, "Add Graphviz to the system PATH for all users"를 클릭하여 path에 추가하여야 함.
#
# ### 위 과정을 마친 후 pip install graphviz로 래퍼 설치
#
# ### 이후 주피터 노트북 서버 프로그램을 재기동하여야 함

# %%
pip install graphviz
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.tree import export_graphviz

# tree.dot 파일을 생성함
export_graphviz(model, out_file = 'tree.dot', 
                class_names = iris.target_names, feature_names = iris.feature_names,
               impurity=True, filled=True)


import graphviz

with open("tree.dot") as f:
    dot_graph = f.read()
    
graphviz.Source(dot_graph)
