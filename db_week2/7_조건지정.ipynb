# %%
#!pip install numpy
import numpy as np
import pandas as pd

# %% [markdown]
# ## 누락된 데이터 처리

# %%
#다음과 같은 데이터를 가정한다.

df = pd.DataFrame(np.random.randn(7,3))
df
# Out:
#           0         1         2
# 0 -0.224249 -0.307291 -1.541354
# 1 -0.580189 -0.340944  0.760566
# 2  0.733609 -0.447845  0.098904
# 3  0.555205 -0.231496 -0.264863
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %%
df.iloc[:4,1] = np.nan

df.iloc[:2,2] = np.nan

df.iloc[1,0] = np.nan

df
# Out:
#           0         1         2
# 0 -0.224249       NaN       NaN
# 1       NaN       NaN       NaN
# 2  0.733609       NaN  0.098904
# 3  0.555205       NaN -0.264863
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %%
# 결측값 제외 함수 : dropna()
# dropna()는 원칙적으로 하나라도 NaN이 있으면 그 행을 제외한다

df.dropna(axis=0)
# Out:
#           0         1         2
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %%
# 만약 해당 행의 모든 요소가 NaN일 때 제외하려면 

df1 = df.dropna(how='all')
df1
# Out:
#           0         1         2
# 0 -0.224249       NaN       NaN
# 2  0.733609       NaN  0.098904
# 3  0.555205       NaN -0.264863
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %%
# 행을 제외하는 것도 동일, 다만 이때 axis=1을 인자로 한다

df1.dropna(axis=1)
# Out:
#           0
# 0 -0.224249
# 2  0.733609
# 3  0.555205
# 4 -1.806941
# 5  0.164165
# 6 -0.500668

# %%
df
# Out:
#           0         1         2
# 0 -0.224249       NaN       NaN
# 1       NaN       NaN       NaN
# 2  0.733609       NaN  0.098904
# 3  0.555205       NaN -0.264863
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %%
# 몇 개 이상의 NaN을 가질 때 제외할 것인가 조건을 주는 방법은..
# thresh = n 의 의미는 해당 행/열에서 NaN이 아닌 값이 n개 이상일 경우만 남긴다는 의미
# NaN의 갯수를 의미하지 않는다

df.dropna(thresh=1)
# Out:
#           0         1         2
# 0 -0.224249       NaN       NaN
# 2  0.733609       NaN  0.098904
# 3  0.555205       NaN -0.264863
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %%
df
# Out:
#           0         1         2
# 0 -0.224249       NaN       NaN
# 1       NaN       NaN       NaN
# 2  0.733609       NaN  0.098904
# 3  0.555205       NaN -0.264863
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %%
# 삭제하는 것이 아니라, 값을 다른 값으로 채워야 할 경우가 많다
# 만약 NaN을 0으로 채워야 한다면...

df.fillna(0)   # fillna() 안에 채울 값을 표시하면 된다
# Out:
#           0         1         2
# 0 -0.224249  0.000000  0.000000
# 1  0.000000  0.000000  0.000000
# 2  0.733609  0.000000  0.098904
# 3  0.555205  0.000000 -0.264863
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %%
# 각 열별로 서로 다른 값으로 채울 수도 있다

df.fillna({0:10, 1:20, 2:30})
# Out:
#            0          1          2
# 0  -0.224249  20.000000  30.000000
# 1  10.000000  20.000000  30.000000
# 2   0.733609  20.000000   0.098904
# 3   0.555205  20.000000  -0.264863
# 4  -1.806941   0.438018  -0.448137
# 5   0.164165   0.601759  -0.656827
# 6  -0.500668   0.521780   1.188909

# %%
# 나아가 함수로 채울 수도 있다
# 0 열은 평균, 1열은 최대, 2열은 최소로 채운다

imputed = df.fillna({0:df[0].mean(), 1:df[1].max(), 2: df[2].min()})
imputed
# Out:
#           0         1         2
# 0 -0.224249  0.601759 -0.656827
# 1 -0.179813  0.601759 -0.656827
# 2  0.733609  0.601759  0.098904
# 3  0.555205  0.601759 -0.264863
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %% [markdown]
# ## 중복 데이터의 제거

# %%
# 때에 따라 중복 데이터를 제거해야 할 경우가 많다.

# 먼저 중복 데이터 여부를 확인하는 방법은...

imputed.duplicated()  #각 row의 값들이 모두 중복이면 True가 된다.
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
# 특정 열 기준으로 해당 열의 중복 값을 제거...

imputed.drop_duplicates(subset=[1, 2])    #칼럼 1, 2의 중복 값을 제거
# Out:
#           0         1         2
# 0 -0.224249  0.601759 -0.656827
# 2  0.733609  0.601759  0.098904
# 3  0.555205  0.601759 -0.264863
# 4 -1.806941  0.438018 -0.448137
# 6 -0.500668  0.521780  1.188909

# %%
# drop_duplicates()는 원칙적으로 앞으로 값을 보존하고, 뒤의 중복을 없앤다.
# 만약 뒤의 값을 보존하려면...

imputed.drop_duplicates([1,2], keep ='last')
# Out:
#           0         1         2
# 2  0.733609  0.601759  0.098904
# 3  0.555205  0.601759 -0.264863
# 4 -1.806941  0.438018 -0.448137
# 5  0.164165  0.601759 -0.656827
# 6 -0.500668  0.521780  1.188909

# %% [markdown]
# ## 특정한 조건으로 값을 걸러내기

# %%
import pandas as pd

df = pd.read_csv('./weather_tmp.csv', encoding = 'utf-8')
df.head()
# Out:
#     지점          일시  평균기온  최저기온  최저기온시각  최고기온  최고기온시각  1시간최다강수량  일강수량  평균풍속  \
# 0  108  2021-01-01  -4.2  -9.8     511   1.6    1447       NaN   NaN   2.0
# 1  108  2021-01-02  -5.0  -8.4     805  -1.4    1346       NaN   NaN   2.6
# 2  108  2021-01-03  -5.6  -9.1     536  -2.0    1238       NaN   NaN   2.0
# 3  108  2021-01-04  -3.5  -8.4     656   0.3    1535       NaN   0.0   1.7
# 4  108  2021-01-05  -5.5  -9.9    2356  -2.1       1       NaN   0.0   2.9
#
#      평균기압  합계일조시간  평균지면온도
# 0  1014.9     6.5    -3.4
# 1  1018.5     9.0    -3.9
# 2  1023.0     5.5    -4.9
# 3  1020.3     4.6    -3.3
# 4  1019.2     8.6    -3.2

# %%
# 위의 데이터프레임에서 1시간 최대강수량, 일강수량 등에서 NaN인 것은
# 측정 자체가 불가능했다기 보다는 단순히 0 대신 NaN으로 표시했을 것으로 보인다.
# NaN 모두를 0으로 채워 넣어보자

df.fillna(0, inplace = True)
df.head()
# Out:
#     지점          일시  평균기온  최저기온  최저기온시각  최고기온  최고기온시각  1시간최다강수량  일강수량  평균풍속  \
# 0  108  2021-01-01  -4.2  -9.8     511   1.6    1447       0.0   0.0   2.0
# 1  108  2021-01-02  -5.0  -8.4     805  -1.4    1346       0.0   0.0   2.6
# 2  108  2021-01-03  -5.6  -9.1     536  -2.0    1238       0.0   0.0   2.0
# 3  108  2021-01-04  -3.5  -8.4     656   0.3    1535       0.0   0.0   1.7
# 4  108  2021-01-05  -5.5  -9.9    2356  -2.1       1       0.0   0.0   2.9
#
#      평균기압  합계일조시간  평균지면온도
# 0  1014.9     6.5    -3.4
# 1  1018.5     9.0    -3.9
# 2  1023.0     5.5    -4.9
# 3  1020.3     4.6    -3.3
# 4  1019.2     8.6    -3.2

# %%
# 특정한 조건을 충족하는 데이터만을 걸러내는 방법

# df[조건] 의 형식으로 걸러 낼수 있다.

# 평균 기온이 -10 이하인 날만 걸러내기

df['평균기온'] < -10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 360    False
# 361    False
# 362    False
# 363    False
# 364    False
# Name: 평균기온, Length: 365, dtype: bool

# %%
day = df[df['평균기온'] < -10]
day
# Out:
#       지점          일시  평균기온  최저기온  최저기온시각  최고기온  최고기온시각  1시간최다강수량  일강수량  평균풍속  \
# 6    108  2021-01-07 -14.5 -16.5     802  -8.4       1       0.0   0.0   4.1
# 7    108  2021-01-08 -14.9 -18.6     812 -10.7    1450       0.0   0.0   3.3
# 8    108  2021-01-09 -12.2 -16.6     614  -7.5    1602       0.0   0.0   2.6
# 358  108  2021-12-25 -11.7 -14.4    2258  -7.3       1       0.0   0.0   3.9
# 359  108  2021-12-26 -12.1 -15.5     817  -7.3    1526       0.0   0.0   3.1
#
#        평균기압  합계일조시간  평균지면온도
# 6    1015.3     0.0    -6.1
# 7    1014.1     9.2    -9.3
# 8    1014.0     9.0    -8.4
# 358  1021.5     9.1    -4.4
# 359  1023.4     9.1    -5.8

# %%
df['최고기온'] > 35
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 360    False
# 361    False
# 362    False
# 363    False
# 364    False
# Name: 최고기온, Length: 365, dtype: bool

# %%
# 최고 기온이 35도 이상인 날만 걸러내기

df[df['최고기온'] > 35]
# Out:
#       지점          일시  평균기온  최저기온  최저기온시각  최고기온  최고기온시각  1시간최다강수량  일강수량  평균풍속  \
# 196  108  2021-07-16  28.8  24.2     508  35.2    1538       0.0   0.0   2.2
# 201  108  2021-07-21  30.5  25.3     556  35.3    1654       0.0   0.0   1.7
# 202  108  2021-07-22  31.2  26.5     621  35.9    1615       0.0   0.0   2.0
# 203  108  2021-07-23  31.2  27.2     541  35.8    1604       0.0   0.0   1.8
# 204  108  2021-07-24  31.7  26.9     548  36.5    1508       0.0   0.0   1.7
# 205  108  2021-07-25  31.5  27.2     542  35.9    1547       0.0   0.0   2.0
# 206  108  2021-07-26  31.2  27.4     608  35.4    1521       0.0   0.0   2.4
# 207  108  2021-07-27  31.1  27.8     601  35.7    1520       0.0   0.0   2.1
# 210  108  2021-07-30  30.5  25.8     559  35.4    1406       0.0   0.0   2.1
#
#        평균기압  합계일조시간  평균지면온도
# 196  1004.3    10.5    32.5
# 201  1002.9    11.3    30.5
# 202  1000.9    11.4    31.4
# 203   999.3    12.4    32.2
# 204   998.2    12.3    32.6
# 205   996.5    13.0    34.2
# 206   994.6    13.2    35.3
# 207   992.9     7.3    33.3
# 210   990.5     7.7    33.5

# %%
# 2021년 7월 달만 걸러내기
#조금 복잡하다.

tmp = []

for i in df['일시']:
    
    if i[:7] =='2021-07':
        tmp.append(1)
    else:
        tmp.append(0)
        
df['7월여부'] = tmp

# %%
df.head()
# Out:
#     지점          일시  평균기온  최저기온  최저기온시각  최고기온  최고기온시각  1시간최다강수량  일강수량  평균풍속  \
# 0  108  2021-01-01  -4.2  -9.8     511   1.6    1447       0.0   0.0   2.0
# 1  108  2021-01-02  -5.0  -8.4     805  -1.4    1346       0.0   0.0   2.6
# 2  108  2021-01-03  -5.6  -9.1     536  -2.0    1238       0.0   0.0   2.0
# 3  108  2021-01-04  -3.5  -8.4     656   0.3    1535       0.0   0.0   1.7
# 4  108  2021-01-05  -5.5  -9.9    2356  -2.1       1       0.0   0.0   2.9
#
#      평균기압  합계일조시간  평균지면온도  7월여부
# 0  1014.9     6.5    -3.4     0
# 1  1018.5     9.0    -3.9     0
# 2  1023.0     5.5    -4.9     0
# 3  1020.3     4.6    -3.3     0
# 4  1019.2     8.6    -3.2     0

# %%
df['일시'][0][:7]
# Out:
# '2021-01'

# %%
df[df['7월여부'] ==1]
# Out:
#       지점          일시  평균기온  최저기온  최저기온시각  최고기온  최고기온시각  1시간최다강수량  일강수량  평균풍속  \
# 181  108  2021-07-01  26.3  21.4     519  31.0    1525       0.0   0.0   1.8
# 182  108  2021-07-02  27.1  23.6     538  31.8    1612       0.0   0.0   2.3
# 183  108  2021-07-03  22.6  19.6    2208  25.7       1      13.8  60.0   3.6
# 184  108  2021-07-04  21.4  19.8       1  23.1    1500       5.3  21.4   2.3
# 185  108  2021-07-05  23.3  20.1     328  26.9    1444       0.0   0.0   1.4
# 186  108  2021-07-06  25.3  21.0     450  30.1    1437       0.0   0.0   1.6
# 187  108  2021-07-07  26.4  23.9     419  29.1    1441      12.4  12.7   1.5
# 188  108  2021-07-08  26.0  23.8     520  29.8    1451       2.7   2.9   2.0
# 189  108  2021-07-09  25.5  23.6     335  29.2    1530       0.0   0.0   1.9
# 190  108  2021-07-10  25.9  23.1     631  29.2    1340       0.2   0.5   2.4
# 191  108  2021-07-11  25.7  24.1     700  27.5    1552       0.4   0.4   2.2
# 192  108  2021-07-12  28.1  23.8     557  32.5    1604       0.0   0.0   1.6
# 193  108  2021-07-13  28.8  26.3     429  31.5    1431       0.0   0.0   1.7
# 194  108  2021-07-14  29.7  26.1     447  33.5    1508       0.0   0.0   2.2
# 195  108  2021-07-15  29.1  25.9    2344  34.5    1347       0.0   0.0   2.1
# 196  108  2021-07-16  28.8  24.2     508  35.2    1538       0.0   0.0   2.2
# 197  108  2021-07-17  29.1  24.7     521  32.8    1557       0.0   0.0   2.3
# 198  108  2021-07-18  29.6  25.7     551  34.1    1546       0.0   0.0   2.1
# 199  108  2021-07-19  26.4  24.0    1532  30.5    1134      65.7  67.4   1.9
# 200  108  2021-07-20  27.9  23.6     532  31.8    1159       0.0   0.0   1.5
# 201  108  2021-07-21  30.5  25.3     556  35.3    1654       0.0   0.0   1.7
# 202  108  2021-07-22  31.2  26.5     621  35.9    1615       0.0   0.0   2.0
# 203  108  2021-07-23  31.2  27.2     541  35.8    1604       0.0   0.0   1.8
# 204  108  2021-07-24  31.7  26.9     548  36.5    1508       0.0   0.0   1.7
# 205  108  2021-07-25  31.5  27.2     542  35.9    1547       0.0   0.0   2.0
# 206  108  2021-07-26  31.2  27.4     608  35.4    1521       0.0   0.0   2.4
# 207  108  2021-07-27  31.1  27.8     601  35.7    1520       0.0   0.0   2.1
# 208  108  2021-07-28  30.4  27.1     600  34.7    1456       0.0   0.0   1.9
# 209  108  2021-07-29  29.6  27.0     529  33.3    1303       0.0   0.0   2.0
# 210  108  2021-07-30  30.5  25.8     559  35.4    1406       0.0   0.0   2.1
# 211  108  2021-07-31  29.8  26.8     538  34.3    1457       2.4   3.0   2.5
#
#        평균기압  합계일조시간  평균지면온도  7월여부
# 181   996.8     8.2    27.4     1
# 182   998.7     7.4    27.2     1
# 183   996.3     0.9    23.5     1
# 184   994.4     0.0    22.2     1
# 185   999.8     0.9    24.6     1
# 186   997.2     4.3    26.8     1
# 187   997.1     1.1    26.6     1
# 188   995.2     2.9    27.0     1
# 189   995.5     3.8    27.0     1
# 190   997.5     4.2    26.9     1
# 191   999.9     0.1    26.3     1
# 192  1000.0     4.9    29.0     1
# 193   999.8     1.4    28.5     1
# 194  1002.1     7.1    30.6     1
# 195  1004.5     8.7    31.8     1
# 196  1004.3    10.5    32.5     1
# 197  1002.1     8.9    32.4     1
# 198  1001.4     8.4    33.1     1
# 199  1003.4     3.1    28.0     1
# 200  1004.4     3.4    28.9     1
# 201  1002.9    11.3    30.5     1
# 202  1000.9    11.4    31.4     1
# 203   999.3    12.4    32.2     1
# 204   998.2    12.3    32.6     1
# 205   996.5    13.0    34.2     1
# 206   994.6    13.2    35.3     1
# 207   992.9     7.3    33.3     1
# 208   992.5     6.5    33.5     1
# 209   991.9     2.2    31.3     1
# 210   990.5     7.7    33.5     1
# 211   990.6     7.7    31.6     1

# %%
# 여러개의 조건으로 동시에 걸러낼 수도 있다. 
# 단 개별 조건을 ()로 묶고, 일반적인 and 대신에 &로 표시한다
# (or조건의 경우는 |)
# ex) 최고 기온이 30도 이상이면서 일강수량이 50 mm 이상인 날

df[(df['최고기온'] >= 30) & (df['일강수량'] >= 50)]
# Out:
#       지점          일시  평균기온  최저기온  최저기온시각  최고기온  최고기온시각  1시간최다강수량  일강수량  평균풍속  \
# 199  108  2021-07-19  26.4  24.0    1532  30.5    1134      65.7  67.4   1.9
#
#        평균기압  합계일조시간  평균지면온도  7월여부
# 199  1003.4     3.1    28.0     1
